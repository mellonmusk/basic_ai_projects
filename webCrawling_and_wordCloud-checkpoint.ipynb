# %% [markdown]
# <h2>Web Crawling </h2>

# %%
# 필요한 라이브러리 설치
# !pip install beautifulsoup4
# !pip install requests
# !pip install wordcloud
# !pip install matplotlib

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from PIL import Image
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
import requests
from bs4 import BeautifulSoup
import re
# Out:
# Requirement already satisfied: beautifulsoup4 in c:\users\peach\anaconda3\lib\site-packages (4.12.3)
# Requirement already satisfied: soupsieve>1.2 in c:\users\peach\anaconda3\lib\site-packages (from beautifulsoup4) (2.5)
# Requirement already satisfied: requests in c:\users\peach\anaconda3\lib\site-packages (2.32.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\peach\anaconda3\lib\site-packages (from requests) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\peach\anaconda3\lib\site-packages (from requests) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\peach\anaconda3\lib\site-packages (from requests) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\peach\anaconda3\lib\site-packages (from requests) (2024.7.4)
# Requirement already satisfied: wordcloud in c:\users\peach\anaconda3\lib\site-packages (1.9.3)
# Requirement already satisfied: numpy>=1.6.1 in c:\users\peach\anaconda3\lib\site-packages (from wordcloud) (1.26.4)
# Requirement already satisfied: pillow in c:\users\peach\anaconda3\lib\site-packages (from wordcloud) (10.4.0)
# Requirement already satisfied: matplotlib in c:\users\peach\anaconda3\lib\site-packages (from wordcloud) (3.9.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\peach\anaconda3\lib\site-packages (from matplotlib->wordcloud) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\peach\anaconda3\lib\site-packages (from matplotlib->wordcloud) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\peach\anaconda3\lib\site-packages (from matplotlib->wordcloud) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\peach\anaconda3\lib\site-packages (from matplotlib->wordcloud) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in c:\users\peach\anaconda3\lib\site-packages (from matplotlib->wordcloud) (24.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\peach\anaconda3\lib\site-packages (from matplotlib->wordcloud) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\peach\anaconda3\lib\site-packages (from matplotlib->wordcloud) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\peach\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)
# Requirement already satisfied: matplotlib in c:\users\peach\anaconda3\lib\site-packages (3.9.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\peach\anaconda3\lib\site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\peach\anaconda3\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\peach\anaconda3\lib\site-packages (from matplotlib) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\peach\anaconda3\lib\site-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: numpy>=1.23 in c:\users\peach\anaconda3\lib\site-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\peach\anaconda3\lib\site-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\peach\anaconda3\lib\site-packages (from matplotlib) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\peach\anaconda3\lib\site-packages (from matplotlib) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\peach\anaconda3\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\peach\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %% [markdown]
# <h3>필요한 tag알아내기</h3>

# %%
# URL 설정
url = 'https://namu.wiki/w/%EC%97%90%EB%AF%B8%EB%84%B4'

# 페이지 요청 및 파싱
response = requests.get(url)
soup = BeautifulSoup(response.text, 'html.parser')

# 본문 태그의 내용만 크롤링
paragraphs = soup.find_all("div",class_="wiki-heading-content")
content = ' '.join([para.get_text() for para in paragraphs])

# '개요' 단어 이후의 모든 'div wiki-link-internal' 태그 내의 링크 추출
start=soup.find(string="개요")
internal_link = start.find_all_next("a",class_="wiki-link-internal")
links = [a['href'] for a in internal_link[:100]]

# %%
#soup
# Out:
# <!DOCTYPE html>
#
# <html lang="ko"><head><meta charset="utf-8"/>
# <meta content="user-scalable=no, initial-scale=1, width=device-width, viewport-fit=cover" name="viewport"/>
# <title>에미넴 - 나무위키</title>
# <meta content="ie=edge" http-equv="x-ua-compatible"/>
# <meta content="the seed" name="generator"/>
# <meta content="yes" name="mobile-web-app-capable"/>
# <meta content="나무위키" name="application-name"/>
# <meta content="나무위키" name="msapplication-tooltip"/>
# <meta content="/w/%EB%82%98%EB%AC%B4%EC%9C%84%ED%82%A4:%EB%8C%80%EB%AC%B8" name="msapplication-starturl"/>
# <meta content="max-image-preview:large" name="robots"/>
# <meta content="에미넴" property="og:title"/>
# <meta content="나무위키" property="og:site_name"/>
# <meta content="//i.namu.wiki/i/bAP5i_T4BvqEzUX8IENtBEGuOsRl2HA0mRWjavmz0FWe4jIVq3qbEuJtm9zm__QiDv2awOleb8JzcYU2dtPe6nZNqFg23DriTWCSXnWOlZjoq4yfVOqBabuytsVB8qW92Gsxn8d41Lvbbf9ls3RKZQ.webp" property="og:image"/>
# <meta content="파일:SlimShadyLPat0_Getty_Ringer.0.jpg 미국   디트로이트  출신 출생 지역은  세인트조" property="og:description"/>
# <meta content="https://namu.wiki/w/%EC%97%90%EB%AF%B8%EB%84%B4" property="og:url"/>
# <meta content="article" property="og:type"/>
# <link href="https://namu.wiki/w/%EC%97%90%EB%AF%B8%EB%84%B4" rel="canonical"/>
# <link href="/opensearch.xml" rel="search" title="나무위키" type="application/opensearchdescription+xml"/>
# <link href="//creativecommons.org/licenses/by-nc-sa/2.0/kr/" rel="copyright"/>
# <meta content="noarchive" name="googlebot"/>
# <meta content="#00a69c" name="theme-color"/>
# <link href="/favicon.svg" rel="icon" sizes="any" type="image/svg+xml"/>
# <link href="/favicon-32.png" rel="icon" sizes="32x32" type="image/png"/>
# <link href="/favicon-192.png" rel="icon" sizes="192x192" type="image/png"/>
# <link href="/img/apple_icon.png" rel="apple-touch-icon"/>
# <script async="" src="https://securepubads.g.doubleclick.net/tag/js/gpt.js"></script><link as="script" crossorigin="" href="/skins/espejo/jetkesqw.b90f567d5e1b825d0d9e.js" rel="prefetch"/><link as="script" crossorigin="" href="/skins/espejo/mpndntzq.893f01520da9d7558740.js" rel="prefetch"/><link as="script" crossorigin="" href="/skins/espejo/vfrwqrvf.35a7ad3a55c370e8443f.js" rel="prefetch"/><link href="/skins/espejo/84.846cf0b4cf78a0c9b931.css" rel="stylesheet"/><link href="/skins/espejo/mpndntzq.893f01520da9d7558740.css" rel="stylesheet"/></head><body><div id="app"><!--[--><!-- --><div class="iR4+oASO bdxIt6Qm" data-v-bb30723d=""><div class="sLPXd6cF pzKabXv6" data-v-2f8b0b50="" data-v-bb30723d=""><div class="ADbFXCIB _8AY-OoJj RCG+IQ0D" data-v-25c821de="" data-v-2f8b0b50=""><!--[--><a class="-LqetAoG" data-v-2f8b0b50="" href="/" title="
0 35.3-28.7 64-64 64H64c-35.3 0-64-28.7-64-64z"></path></svg><span class="WmjKrufy" data-v-2f8b0b50="">특수 기능</span><svg class="o-DtPD+7" data-v-2f8b0b50="" height="1em" viewbox="0 0 320 512" xmlns="http://www.w3.org/2000/svg"><path d="M137.4 374.6c12.5 12.5 32.8 12.5 45.3 0l128-128c9.2-9.2 11.9-22.9 6.9-34.9s-16.6-19.8-29.6-19.8L32 192c-12.9 0-24.6 7.8-29.6 19.8s-2.2 25.7 6.9 34.9l128 128z"></path></svg></a><!--]--><!-- --></div></div><div class="JJ-18pbM Js0WqKfs" data-v-2f8b0b50=""><div class="Xo0BPgat nBmNVxtm" data-v-2f8b0b50="" data-v-bfe42644=""><a class="TLSQtOC3 wBbOI7Ho" data-v-bfe42644="" href="/random" title="아무 문서로 이동"><svg class="Hr8EE8qB" data-v-bfe42644="" viewbox="0 0 512 512" xmlns="http://www.w3.org/2000/svg"><path d="M403.8 34.4c12-5 25.7-2.2 34.9 6.9l64 64c6 6 9.4 14.1 9.4 22.6s-3.4 16.6-9.4 22.6l-64 64c-9.2 9.2-22.9 11.9-3 ...

# %% [markdown]
# <h2> 문제점 </h2>
# 메모리 문제
#
# 한국어 필터링의 문제(영어와 다르게 조사가 붙음) ->외부 라이브러리 이용
# 사람들이 함께 만들어나가는 식이다보니 형식이 일정하지 않음. 문서마다 태그 처리가 다른 경우가 있음.

# %% [markdown]
# <h3>에미넴</h3>

# %%
# URL 설정
url = 'https://namu.wiki/w/%EC%97%90%EB%AF%B8%EB%84%B4'

# 페이지 요청 및 파싱
response = requests.get(url)
soup = BeautifulSoup(response.text, 'html.parser')

# 불필요한 키워드 필터링
stopwords = {'더', '은','는', '를', '의', '통해','또한','있다','이','가','을','대해','한','중','등', '및','한다','있다','했다','이후','수','때','그리고','대한','된','그','있는'}

# 본문 태그의 내용만 크롤링
paragraphs = soup.find_all("div",class_="wiki-heading-content")
content = ' '.join([para.get_text() for para in paragraphs])
content = re.sub(r'[^\w\s]', '', content) # Remove punctuation from content
filtered_content = ' '.join([word for word in content.split() if word not in stopwords])

# '개요' 단어 이후의 모든 'div wiki-link-internal' 태그 내의 링크 추출
start=soup.find(string="개요")
internal_link = start.find_all_next("a",class_="wiki-link-internal")
links = [a['href'] for a in internal_link[:10]]

# 추출한 링크 내용 크롤링
for url in links:
    response = requests.get(f'https://namu.wiki/'+url)
    soup = BeautifulSoup(response.text, 'html.parser')
    paragraphs = soup.find_all("div",class_="wiki-heading-content")
    content = ' '.join([para.get_text() for para in paragraphs])
    filtered = ''.join([word for word in content.split() if word not in stopwords])


# 한글 폰트 경로 설정 (나눔고딕 폰트 사용)
font_path = 'NanumSquareOTF_acB.otf'


mask = np.array(Image.open('oval_shape.jpg'))
# Word Cloud 생성
wordcloud = WordCloud(font_path=font_path, width=1000, height=500, background_color='white', mask=mask).generate(filtered_content)

# Word Cloud 시각화
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.savefig("eminemonly.pdf")
plt.show()

# 링크 출력
print("Extracted Links:")
for link in links:
    print(link)
# Out:
# Extracted Links:
# /w/%EB%AF%B8%EA%B5%AD
# /w/%EB%94%94%ED%8A%B8%EB%A1%9C%EC%9D%B4%ED%8A%B8
# /w/%EB%9E%98%ED%8D%BC
# /w/%EB%B0%B0%EC%9A%B0
# /w/%ED%9D%91%EC%9D%B8
# /w/%ED%9E%99%ED%95%A9
# /w/%EB%B0%B1%EC%9D%B8
# /w/%EB%A1%9C%ED%81%B0%EB%A1%A4%20%EB%AA%85%EC%98%88%EC%9D%98%20%EC%A0%84%EB%8B%B9
# /w/EGOT
# /w/Mathers

# %% [markdown]
# <h3>LA</h3>

# %%
# URL 설정
url = 'https://namu.wiki/w/%EB%A1%9C%EC%8A%A4%EC%95%A4%EC%A0%A4%EB%A0%88%EC%8A%A4'

# 페이지 요청 및 파싱
response = requests.get(url)
soup = BeautifulSoup(response.text, 'html.parser')

# 불필요한 키워드 필터링
stopwords = {'더', '은','는', '를', '의', '통해','또한','있다','이','가','을','대해','한','중','등', '및','한다','있다','했다','이후','수','때','그리고','대한','된','그','있는'}

# 본문 태그의 내용만 크롤링
paragraphs = soup.find_all("div",class_="wiki-heading-content")
content = ' '.join([para.get_text() for para in paragraphs])
content = re.sub(r'[^\w\s]', '', content) # Remove punctuation from content
filtered_content = ' '.join([word for word in content.split() if word not in stopwords])

# '개요' 단어 이후의 모든 'div wiki-link-internal' 태그 내의 링크 추출
start=soup.find(string="개요")
internal_link = start.find_all_next("a",class_="wiki-link-internal")
links = [a['href'] for a in internal_link[:10]]

# 추출한 링크 내용 크롤링
for url in links:
    response = requests.get(f'https://namu.wiki/'+url)
    soup = BeautifulSoup(response.text, 'html.parser')
    paragraphs = soup.find_all("div",class_="wiki-heading-content")
    content = ' '.join([para.get_text() for para in paragraphs])
    filtered = ''.join([word for word in content.split() if word not in stopwords])


# 한글 폰트 경로 설정 (나눔고딕 폰트 사용)
font_path = 'NanumSquareOTF_acB.otf'


mask = np.array(Image.open('oval_shape.jpg'))
# Word Cloud 생성
wordcloud = WordCloud(font_path=font_path, width=1000, height=500, background_color='white', mask=mask).generate(filtered_content)

# Word Cloud 시각화
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.savefig("laonly.pdf")
plt.show()

# 링크 출력
print("Extracted Links:")
for link in links:
    print(link)
# Out:
# Extracted Links:
# /w/%EC%BA%98%EB%A6%AC%ED%8F%AC%EB%8B%88%EC%95%84
# /w/%EB%AF%B8%EA%B5%AD
# /w/%EB%89%B4%EC%9A%95%EC%8B%9C
# /w/LA%20%EB%8B%A4%EC%A0%80%EC%8A%A4
# /w/%ED%95%A0%EB%A6%AC%EC%9A%B0%EB%93%9C
# /w/%EC%84%B8%EA%B3%84%EB%8F%84%EC%8B%9C
# /w/%EC%A7%80%EC%A4%91%ED%95%B4%EC%84%B1%20%EA%B8%B0%ED%9B%84
# /w/%EB%89%B4%EC%9A%95
# /w/%EC%9B%8C%EC%8B%B1%ED%84%B4%20D.C.
# /w/%EC%83%8C%ED%94%84%EB%9E%80%EC%8B%9C%EC%8A%A4%EC%BD%94

# %%
filtered_content
# Out:
# 'Los Angeles California로스앤젤레스는 캘리포니아 주 나아가 미국 서부에서 제일 크고 인구가 많은 도시이자 미국 전체에서는 뉴욕시에 이어 두 번째로 큰 도시다67 캘리포니아 남부8의 중심지로서 문화적 다양성과 LA 다저스 할리우드를 필두로 대중문화 산업 등으로 유명한 유수의 세계도시이다커다란 도시규모와 활발한 경제 문화산업의 중심지 뛰어난 아케이드성 따뜻한 지중해성 기후 아름다운 해변과 어우러진 특유의 휴양지와 자유로운 분위기에 힘입어 문화 산업이 발전한 도시로 잘 알려져 있지만 이에 동시에 타 미국의 대도시와 공유하는 특성인 일부 지역의 불안한 치안 상태와 노숙자 문제 지나치게 개방적인 분위기 여러 가지 모습을 동시에 지닌 도시기도 하다 뉴욕 워싱턴 DC에서 비행기로 약 5시간 30분 샌프란시스코에서 비행기로 약 1시간 30분 걸린다 줄여서 LA엘에이라고 많이 부른다 Los Angeles는 스페인어로 천사들이라는 단순한 뜻을 가지고 Los는 남성형 복수 명사에 붙는 정관사로 영어의 the와 비슷한 것이고 angeles는 천사들이라는 의미로 영어의 angels에 해당한다이런 이름이 붙은 유래는 다음과 같다 스페인 제국 군대가 현재 LA 지역에 정착하면서 El Pueblo de Nuestra Señora la Reina de los Ángeles del Río Porciúncula 포르시운꿀라 강9에 천사들의 여왕인 성모10의 마을11 라는 이름을 지었는데 어느 샌가 중간의 로스 앙헬레스Los Angeles만 남아 멕시코 시절에는 시우다드 데 로스 앙헬레스Ciudad de los Angeles 천사들의 도시라 하다가 미국령이 되면서 그마저도 줄어들어 로스앤젤레스Los Angeles로 굳어진 것이다 본래는 성모의 마을이었는데 줄어들다 보니 어느샌가 천사의 마을이 되어버린 주객전도 지명이다이 문서의 제목인 로스앤젤레스가 올바른 표기이지만 실상은 로스엔젤레스 로스엔젤리스 로스앤절러스 로스안젤레스 등등 여러 표기가 혼재되어 외래어표기법에 따른 표기는 로스앤젤레스인데 에인절Angel의 잘못된 표기인 엔젤의 영향을 받아 로스엔젤레스라는 표기도 많이 쓰인다 영문 철자는 Angel과 같으나 로스에인절레스가 아닌 이유는 A가 Angel과 달리 æ로 발음되기 때문인데 정확한 발음은 lɔːsǽndƷələslìːz로 이를 한글로 옮길 경우 로스 앤절러스 또는 로스 앤절리즈가 된다 물론 스페인어가 원어이므로 스페인어권 국가에서 이곳을 지칭할 때는 로스 앙헬레스라고 발음하며 표기도 Los Ángeles로 악센트까지 포함하여 적는다 위 도시와 이름이 같은 로스 앙헬레스라는 도시도 라틴 아메리카 국가에 여럿 있기도 하다한자식 가차 표기로는 나성두음법칙을 적용하지 않으면 라성 羅城이라고 쓴다 외국 지명의 한자 음차 표기는 보통 중국에서 중국어 발음에 맞는 한자를 차용해서 사용하던 것을 한국 한자음대로 받아들인 경우가 많으며 약칭 LA가 왠지 라로 읽힐 법하다는 것과는 전혀 관계가 없다12 정확히는 19세기 중국에서 사용되던 羅省枝利나성지리13에서 나성羅省을 따온 후 한국 한자음 기준으로 省성과 발음이 같고 도시를 의미하는 城성으로 두 번째 글자의 표기를 바꾸었다고 보는 것이 설득력 있다14 옛날 노래 나성에 가면의 나성이 바로 이곳이다 지금도 LA 한인 교회의 상당수가 나성XX교회같은 이름을 붙이고 이곳 총영사관에서 발행하는 공문서는 주라성총영사관 이라는 직인이 찍혔다 현재는 주 로스앤젤레스 총영사관으로 바꿨다 일본에서는 ロサンゼルス로산제루스 혹은 羅府라고 쓴다 LA의 역사는 스페인 제국 식민지로 출발하였다 서구 역사관 기준 지역 최초 발견은 로드리게스 카브리요가 이끄는 탐험대에 의해 시작되었다1781년 스페인 제국의 캘리포니아 총독 페르난도 리베라 몬카다Fernando Rivera y Moncada가 모집한 두 개의 정착민 그룹이 도시로써 LA역사의 첫 삽을 펐다 초기에는 가축 방목과 와인 생산지로 출발
틀 도쿄 아르메니아의 리틀 아르메니아 에티오피아의 리틀 에티오피아 태국의 타이 타운 등이 있으며 외에도 이탈리아 러시아 문화권 공동체도 골고루 분포되어 이민자 국가인 미국 내에서도 진정으로 글로벌화된 구역이라고 할 있다LA는 생활권이 좀 복잡한 편인데 맨해튼이나 브루클린처럼 도시 중심에 고급 주택들이 있는주로 최고급 아파트 뉴욕과 달리 중심가와 부촌들이 거리가 편이다 LA 다운타운 지역은 거의 사무용 건물들로 이뤄져 있고18 멀지 않은 곳에 잉글우드 같은 낙후 지역 외곽 지역에 베벌리힐스나 할리우드 부촌이 있으며 중산층들은 베드 타운이라고 불리는 글렌데일이나 라카나다 위성도시에 거주하는 편이 많다 이처럼 넓은 지역에 퍼져 사람들이 출근 시간에 일제히 시내로 몰려들면 헬게이트가 펼쳐지는데 이게 바로 유명한 LA의 러시 아워다 대한민국의 추자도 거문도 일본의 시모노세키와 비슷한 위도에 있고 스텝 기후에 가까운 지중해성 기후 지역이다연 평균 기온은 19도로 동위도 지역 대비 상당히 높은 편 월 평균 기온의 경우도 최한월 1월이 144도 최난월 8월이 23 ...

# %% [markdown]
# <h1>과제</h1>

# %% [markdown]
# 나무위키 도메인의 이름, 주소
#
# 1.로스앤젤레스 - 나무위키
# https://namu.wiki/w/%EB%A1%9C%EC%8A%A4%EC%95%A4%EC%A0%A4%EB%A0%88%EC%8A%A4
#
#
# 2.에미넴 - 나무위키
# https://namu.wiki/w/%EC%97%90%EB%AF%B8%EB%84%B4

# %%
# !pip install konlpy
from konlpy.tag import Okt
from collections import Counter
# Out:
# Requirement already satisfied: konlpy in c:\users\peach\anaconda3\lib\site-packages (0.6.0)
# Requirement already satisfied: JPype1>=0.7.0 in c:\users\peach\anaconda3\lib\site-packages (from konlpy) (1.5.0)
# Requirement already satisfied: lxml>=4.1.0 in c:\users\peach\anaconda3\lib\site-packages (from konlpy) (5.3.0)
# Requirement already satisfied: numpy>=1.6 in c:\users\peach\anaconda3\lib\site-packages (from konlpy) (1.26.4)
# Requirement already satisfied: packaging in c:\users\peach\anaconda3\lib\site-packages (from JPype1>=0.7.0->konlpy) (24.1)

# %%
# 불필요한 키워드 필터링
# file downloaded from https://gist.github.com/spikeekips/40eea22ef4a89f629abd87eed535ac6a
ko_stopwords_path = "stopwords-ko.txt"

with open(ko_stopwords_path, encoding='utf-8') as f:
    stopwords= f.readlines()
stopwords = [x.strip() for x in stopwords]

# add my stopwords
my_stopwords = ['통해','또한','있다','대해', '한다','있다','했다','이후','그리고','대한',
                '있는','적이','것도','하고','상당히','없는','있지만','있는데','당시','자신의','볼','있으며', '실제로','것을','아닌','인해','그냥','등이', '아니라',
                '이전', '역사','문단','이전','주로','것이','된다','있고',
                '상위', '문서', '내용', '누설', '아래', '해당', '설명', '표기', '추가', '모든', '사용', '매우', '가장', '많은','많이','역시','위해','다시','그의','등의',
                '줄거리', '상황', '편집', '틀', '경우', '때문', '모습', '정도', '이후', '사실', '생각', '인물','나는','나의','내가','이는','것이다',
                '이름', '년월','문서의','같은','특히','하는','문서를의','문단을의','것은','펼치기','접기','것은','자세한','내용은','부분을','참조하십시오','참고하십시오']
for stopword in my_stopwords:
    stopwords.append(stopword)

# %%
def wordcloud_for_articles(url, wordcloud_title):
    # 페이지 요청 및 파싱
    response = requests.get(url)
    soup = BeautifulSoup(response.text, 'html.parser')


    # 본문 태그의 내용만 크롤링
    paragraphs = soup.find_all("div", class_="wiki-heading-content")

    content = ' '.join([para.get_text() for para in paragraphs])
    # Remove punctuation from content
    content = re.sub(r'[^\w\s]', '', content) 
    # stopword 필터링
    filtered_content = ' '.join([word for word in content.split() if word not in stopwords])
    byte_content = bytearray(filtered_content, 'utf-8') # memory error 방지

    # '개요' 단어 이후의 모든 'div wiki-link-internal' 태그 내의 링크 추출
    start=soup.find(string="개요")
    internal_link = start.find_all_next("a",class_="wiki-link-internal")
    links = [a['href'] for a in internal_link[:100]]

    # 추출한 링크 내용 크롤링
    for url in links:
        response = requests.get(f'https://namu.wiki/'+url)
        soup = BeautifulSoup(response.text, 'html.parser')
        paragraphs = soup.find_all("div",class_="wiki-heading-content")
        content = ' '.join([para.get_text() for para in paragraphs])
        content = re.sub(r'[^\w\s]', '', content) # Remove punctuation from content
        filtered = ' '.join([word for word in content.split() if word not in stopwords])
        # This code prevents memory error
        tmp = bytearray(filtered, 'utf-8')
        byte_content.extend(tmp)

    # decode
    filtered_result = byte_content.decode()
    
    # konlpy의 형태소 분석기로 명사 단위의 키워드를 추출
    nouns_tagger = Okt()
    nouns = nouns_tagger.nouns(filtered_result)
    count = Counter(nouns)
    # count중 길이가 1인 단어 제거 
    # 예: '더', '은','는', '를', '의', '이','가','을','한','중','등','수','때','된','그','후','다','및','판','번','잘','할'
    removed_content= ' '.join([x for x in count if len(x) > 1])
    # 어떤 단어가 몇 번 나오는지 알기 위해 추가
    removed_counter = Counter({x : count[x] for x in count if len(x) > 1})
    
    # 한글 폰트 경로 설정 (나눔고딕 폰트 사용)
    font_path = 'NanumSquareOTF_acB.otf'


    mask = np.array(Image.open('oval_shape.jpg'))
    # Word Cloud 생성
    wordcloud = WordCloud(font_path=font_path, width=1000, height=500, background_color='white', mask=mask).generate(removed_content)
    
    # Word Cloud 시각화
    plt.figure(figsize=(10, 5))
    plt.imshow(wordcloud, interpolation='bilinear')
    plt.axis('off')
    plt.savefig(wordcloud_title)
    plt.show()

    # 링크 출력
    print("Extracted Links:")
    for link in links:
        print(link)
        
    return removed_counter

# %%
eminem_word_result = wordcloud_for_articles("https://namu.wiki/w/%EC%97%90%EB%AF%B8%EB%84%B4", "eminem.pdf")
# Out:
# Extracted Links:
# /w/%EB%AF%B8%EA%B5%AD
# /w/%EB%94%94%ED%8A%B8%EB%A1%9C%EC%9D%B4%ED%8A%B8
# /w/%EB%9E%98%ED%8D%BC
# /w/%EB%B0%B0%EC%9A%B0
# /w/%ED%9D%91%EC%9D%B8
# /w/%ED%9E%99%ED%95%A9
# /w/%EB%B0%B1%EC%9D%B8
# /w/%EB%A1%9C%ED%81%B0%EB%A1%A4%20%EB%AA%85%EC%98%88%EC%9D%98%20%EC%A0%84%EB%8B%B9
# /w/EGOT
# /w/Mathers
# /w/%EC%96%BC%ED%84%B0%20%EC%97%90%EA%B3%A0
# /w/%EB%8C%80%EC%A4%91%EC%9D%8C%EC%95%85
# /w/%ED%9E%99%ED%95%A9
# /w/%ED%9E%99%ED%95%A9
# /w/%EA%B2%8C%EC%8A%A4%ED%8A%B8
# /w/%EB%9D%BC%ED%82%B4
# /w/%EB%B9%85%20%EB%8C%80%EB%94%94%20%EC%BC%80%EC%9D%B8
# /w/%EC%95%84%EC%9D%B4%EC%8A%A4%20%ED%81%90%EB%B8%8C
# /w/Andre%203000
# /w/Redman
# /w/LL%20Cool%20J
# /w/Run%20DMC
# /w/%EB%9D%BC%ED%82%B4
# /w/%EB%8B%A4%EC%9D%B4%EC%95%84%EB%AA%AC%EB%93%9C%20%EB%B0%94
# /w/%EB%B2%A0%EB%B2%8C%EB%A6%AC%ED%9E%90%EC%8A%A4
# /w/%EB%A7%90%EB%A6%AC%EB%B6%80
# /w/UCLA
# /w/%EC%9B%A8%EC%8A%A4%ED%8A%B8%EC%9A%B0%EB%93%9C
# /w/%ED%95%A0%EB%A6%AC%EC%9A%B0%EB%93%9C
# /w/20%EC%84%B8%EA%B8%B0%20%ED%8F%AD%EC%8A%A4

# %%
eminem_word_result
# Out:
# Counter({'미국': 1607,
#          '흑인': 1346,
#          '사람': 869,
#          '앨범': 863,
#          '디트로이트': 769,
#          '음악': 655,
#          '경우': 644,
#          '마약': 638,
#          '힙합': 600,
#          '한국': 590,
#          '에미넴': 576,
#          '정도': 552,
#          '지역': 538,
#          '백인': 527,
#          '영상': 493,
#          '사용': 481,
#          '시작': 450,
#          '래퍼': 439,
#          '문제': 433,
#          '발매': 426,
#          '도시': 406,
#          '인종': 399,
#          '자살': 376,
#          '세계': 370,
#          '속령': 370,
#          '권총': 369,
#          '행정구': 362,
#          '현재': 352,
#          '관련': 345,
#          '생각': 334,
#          '국가': 329,
#          '영화': 328,
#          '개인': 321,
#          '인구': 312,
#          '이름': 304,
#          '알리': 303,
#          '사회': 300,
#          '활동': 299,
#          '대표': 292,
#          '대부분': 291,
#          '공연': 290,
#          '때문': 287,
#          '가사': 284,
#          '이유': 283,
#          '드레': 283,
#          '하나': 281,
#          '이후': 277,
#          '캘리포니아': 277,
#          '자격': 274,
#          '사실': 264,
#          '경기': 257,
#          '아프리카': 250,
#          '문화': 248,
#          '배우': 247,
#          '자체': 244,
#          '최고': 243,
#          '평가': 243,
#          '자신': 242,
#          '범죄': 239,
#          '그룹': 238,
#          '사건': 238,
#          '기도': 237,
#          '본인': 236,
#          '드레이크': 236,
#          '의미': 233,
#          '수준': 231,
#          '타이슨': 229,
#          '일본': 227,
#          '아티스트': 225,
#          '영국': 225,
#          '기록': 221,
#          '노래': 220,
#          '정부': 219,
#          '수상': 218,
#          '영향': 216,
#          '존재': 216,
#          '광고': 214,
#          '거나': 213,
#          '상황': 212,
#          '선수': 211,
#          '지금': 210,
#          '지미': 210,
#          '시절': 204,
#          '방송': 204,
#          '사이': 202,
#          '가지': 200,
#          '일부': 195,
#          '아예': 193,
#          '빌보드': 192,
#          '싱글': 191,
#          '여러': 189,
#          '기준': 189,
#          '유럽': 189,
#          '이상': 188,
#          '켄드릭': 187,
#          '포함': 185,
#          '채널': 182,
#          '대통령': 182,
#          '발표': 180,
#          '밴드': 180,
#          '재생': 179,
#          '뮤지션': 179,
#          '유튜브': 178,
#          '등장': 177,
#          '단어': 177,
#          '인기': 176,
#          '상태': 175,
#          '동영상': 174,
#          '전체': 174,
#          '처음': 172,
#          '가수': 168,
#          '주의': 168,
#          '부분': 167,
#          '역사': 166,
#          '참여': 164,
#          '표현': 163,
#          '기능': 163,
#          '댓글': 163,
#          '북한': 161,
#          '데뷔': 160,
#          '이자': 160,
#          '작업': 160,
#          '직접': 158,
#          '참고': 158,
#          '공개': 157,
#          '출신': 155,
#          '대한민국': 155,
#          '지원': 155,
#          '편이': 154,
#          '디스': 154,
#          '모습': 153,
#          '오렌지': 152,
#          '로서': 152,
#          '시리즈': 152,
#          '정규': 151,
#          '관리': 151,
#          '수익': 151,
#          '만화': 150,
#          '차트': 148,
#          '시간': 148,
#          '계속': 147,
#          '발생': 147,
#          '프로듀서': 145,
#          '경제': 145,
#          '이전': 144,
#          '언급': 143,
#          '스타일': 143,
#          '최초': 143,
#          '게임': 142,
#          '사진': 141,
#          '인종차별': 141,
#          '여성': 141,
#          '멤버': 140,
#          '닥터': 140,
#          '이용': 140,
#          '비트': 139,
#          '사망': 139,
#          '인물': 139,
#          '상대': 139,
#          '선정': 137,
#          '환각': 137,
#          '뉴욕': 136,
#          '세기': 135,
#          '평균': 135,
#          '로큰롤': 134,
#          '헨드릭스': 134,
#          '명예': 133,
#          '시기': 133,
#          '수도': 133,
#          '달리': 133,
#          '이기': 133,
#          '대중': 133,
#          '차이': 132,
#          '제외': 132,
#          '전쟁': 132,
#          '출연': 131,
#          '트랙': 130,
#          '과거': 130,
#          '우리': 130,
#          '달러': 130,
#          '경찰': 129,
#          '중국': 129,
#          '뉴스': 129,
#          '음반': 127,
#          '장르': 127,
#          '시대': 127,
#          '자동차': 127,
#          '아버지': 126,
#          '노예': 126,
#          '비율': 126,
#          '펀치': 125,
#          '이야기': 124,
#          '현대': 124,
#          '결과': 124,
#          '캐나다': 124,
#          '민족': 124,
#          '자주': 123,
#          '공식': 123,
#          '나라': 123,
#          '마이클': 123,
#          '역사상': 122,
#          '당시': 122,
#          '마이크': 122,
#          '드라마': 122,
#          '장면': 122,
#          '아시아': 121,
#          '영어': 120,
#          '여기': 119,
#          '버섯': 119,
#          '복싱': 119,
#          '위반': 118,
#          '친구': 117,
#          '크게': 117,
#          '서로': 117,
#          '합의': 117,
#          '캐릭터': 116,
#          '거리': 116,
#          '관계': 115,
#          '무대': 115,
#          '계획': 115,
#          '행위': 115,
#          '보고': 114,
#          '잭슨': 114,
#          '연주': 113,
#          '수록': 112,
#          '머리': 112,
#          '기타': 112,
#          '그대로': 111,
#          '소리': 111,
#          '해당': 111,
#          '작가': 111,
#          '라킴': 110,
#          '최근': 110,
#          '일반': 110,
#          '실제': 110,
#          '남성': 110,
#          '묘사': 109,
#          '서부': 109,
#          '블루스': 109,
#          '판매': 108,
#          '전당': 108,
#          '전성기': 108,
#          '그녀': 108,
#          '비판': 108,
#          '라이브': 108,
#          '부문': 108,
#          '중심': 107,
#          '취급': 106,
#          '인터뷰': 106,
#          '진행': 106,
#          '남부': 106,
#          '분류': 106,
#          '프로': 105,
#          '사례': 104,
#          '서비스': 104,
#          '독자': 103,
#          '스트리밍': 103,
#          '스타': 103,
#          '마찬가지': 103,
#          '피처링': 103,
#          '아이': 102,
#          '원래': 102,
#          '후보': 102,
#          '설정': 102,
#          '연구': 102,
#          '총기': 102,
#          '주장': 101,
#          '해도': 101,
#          '배경': 101,
#          '피부': 101,
#          '성공': 100,
#          '인식': 100,
#          '작품': 100,
#          '기간': 100,
#          '실력': 99,
#          '내용': 99,
#          '프로그램': 99,
#          '중앙': 99,
#          '라면': 99,
#          '방식': 98,
#          '정신': 98,
#          '정치': 98,
#          '논란': 98,
#          '보이': 98,
#          '해외': 98,
#          '위원회': 98,
#          '스포츠': 98,
#          '보통': 98,
#          '제공': 98,
#          '칸예': 97,
#          '차지': 97,
#          '생활': 97,
#          '결정': 96,
#          '제목': 96,
#          '반응': 96,
#          '나이': 96,
#          '아메리카': 96,
#          '소지': 96,
#          '레코드': 95,
#          '보기': 95,
#          '무료': 95,
#          '스턴': 95,
#          '발음': 94,
#          '운동': 94,
#          '확인': 94,
#          '개발': 94,
#          '기본': 94,
#          '뮤지컬': 94,
#          '브라운': 93,
#          '월드': 93,
#          '미국인': 93,
#          '원주민': 93,
#          '방법': 93,
#          '사이트': 93,
#          '만화가': 92,
#          '기사': 92,
#          '인도': 92,
#          '사고': 91,
#          '이제': 91,
#          '그것': 91,
#          '향정신성의약품': 91,
#          '라인': 90,
#          '제임스': 90,
#          '사운드': 90,
#          '스톤': 90,
#          '러시아': 90,
#          '재산': 90,
#          '보컬': 90,
#          '계정': 90,
#          '주요': 89,
#          '치안': 89,
#          '오브': 89,
#          '대중음악': 88,
#          '유지': 88,
#          '중독': 88,
#          '최대': 88,
#          '국내': 88,
#          '서울': 88,
#          '재배': 88,
#          '스티': 87,
#          '교육': 87,
#          '초기': 87,
#          '마지막': 87,
#          '시도': 87,
#          '환경': 86,
#          '위치': 86,
#          '독일': 86,
#          '시장': 86,
#          '어머니': 85,
#          '약물': 85,
#          '피쳐링': 85,
#          '공화국': 85,
#          '멕시코': 85,
#          '프랑스': 85,
#          '법률': 85,
#          '소총': 85,
#          '특징': 85,
#          '챔피언': 85,
#          '물질': 85,
#          '정말': 84,
#          '성적': 84,
#          '반면': 84,
#          '의견': 84,
#          '목록': 84,
#          '대신': 84,
#          '수가': 84,
#          '무기': 84,
#          '비롯': 83,
#          '영향력': 83,
#          '제대로': 83,
#          '중이': 83,
#          '문서': 83,
#          '불법': 83,
#          '사업': 83,
#          '레이': 82,
#          '선언': 82,
#          '성향': 82,
#          '주인공': 82,
#          '목적': 82,
#          '스포티파이': 81,
#          '민주당': 81,
#          '연기': 80,
#          '증가': 80,
#          '조지': 80,
#          '능력': 79,
#          '스눕': 79,
#          '투어': 79,
#          '여자': 79,
#          '제작': 79,
#          '하나로': 78,
#          '점점': 78,
#          '더욱': 78,
#          '과정': 78,
#          '최우수': 78,
#          '시카고': 78,
#          '이하': 78,
#          '크리스': 78,
#          '발전': 77,
#          '전설': 77,
#          '솔로': 77,
#          '투팍': 77,
#          '비교': 77,
#          '피부색': 77,
#          '분위기': 76,
#          '라임': 76,
#          '라마': 76,
#          '결성': 76,
#          '리아나': 76,
#          '구성': 76,
#          '인정': 76,
#          '규모': 76,
#          '주민': 76,
#          '발견': 76,
#          '유저': 76,
#          '개최': 76,
#          '보이즈': 75,
#          '기존': 75,
#          '구분': 75,
#          '구조': 75,
#          '회사': 75,
#          '가족': 74,
#          '설립': 74,
#          '인간': 74,
#          '주목': 74,
#          '표시': 74,
#          '이미지': 74,
#          '자리': 73,
#          '웨인': 73,
#          '뮤직': 73,
#          '한국인': 73,
#          '선택': 73,
#          '산업': 73,
#          '설치': 73,
#          '건물': 73,
#          '감독': 73,
#          '진짜': 72,
#          '연방': 72,
#          '히스패닉': 72,
#          '업계': 72,
#          '연도': 72,
#          '대상': 72,
#          '라운드': 72,
#          '블랙': 72,
#          '다음': 71,
#          '효과': 71,
#          '커리어': 71,
#          '페이지': 71,
#          '이슬람': 71,
#          '막장': 70,
#          '흑역사': 70,
#          '사랑': 70,
#          '버전': 70,
#          '인터넷': 70,
#          '에릭': 70,
#          '상업': 69,
#          '계약': 69,
#          '타이': 69,
#          '예정': 69,
#          '거주': 69,
#          '대도시': 69,
#          '용어': 69,
#          '기업': 69,
#          '누구': 69,
#          '모델': 69,
#          '유전자': 69,
#          '처벌': 69,
#          '음원': 69,
#          '결혼': 68,
#          '설명': 68,
#          '현실': 68,
#          '분야': 68,
#          '집단': 68,
#          '센터': 68,
#          '유전': 68,
#          '제이': 67,
#          '웨스트': 67,
#          '거기': 67,
#          '학교': 67,
#          '그래미': 67,
#          '존스': 67,
#          '클레이': 67,
#          '무려': 66,
#          '아이스': 66,
#          '녹음': 66,
#          '단체': 66,
#          '치료': 66,
#          '변화': 66,
#          '히트': 66,
#          '스페인': 66,
#          '명의': 66,
#          '사항': 66,
#          '디스전': 65,
#          '로직': 65,
#          '개념': 65,
#          '제한': 65,
#          '정보': 65,
#          '가능성': 65,
#          '금지': 65,
#          '살인': 65,
#          '레드': 65,
#          '토니상': 65,
#          '경향': 64,
#          '완성': 64,
#          '자기': 64,
#          '소득': 64,
#          '전혀': 64,
#          '로스앤젤레스': 64,
#          '기반': 64,
#          '대마': 64,
#          '필드': 64,
#          '헤비급': 64,
#          '역대': 63,
#          '목소리': 63,
#          '제국': 63,
#          '압도': 63,
#          '필요': 63,
#          '세상': 63,
#          '라며': 62,
#          '자유': 62,
#          '발언': 62,
#          '현상': 62,
#          '차별': 62,
#          '발달': 62,
#          '생산': 62,
#          '신체': 62,
#          '유통': 62,
#          '보도': 62,
#          '데이비드': 62,
#          '동부': 61,
#          '준비': 61,
#          '유명': 61,
#          '조사': 61,
#          '아주': 61,
#          '언론': 61,
#          '펑크': 61,
#          '회의': 61,
#          '동아시아': 61,
#          '시티': 61,
#          '자동': 61,
#          '무하마드': 60,
#          '적도': 60,
#          '행동': 60,
#          '피해': 60,
#          '관심': 60,
#          '복용': 60,
#          '예전': 60,
#          '업로드': 60,
#          '퍼포먼스': 60,
#          '방문': 60,
#          '전국': 60,
#          '정책': 60,
#          '인류': 60,
#          '토론': 60,
#          '복서': 60,
#          '판매량': 59,
#          '세대': 59,
#          '레전드': 59,
#          '먼저': 59,
#          '다운': 59,
#          '나스': 59,
#          '주변': 59,
#          '이건': 59,
#          '참조': 59,
#          '데이브': 59,
#          '소속': 59,
#          '수입': 59,
#          '규제': 59,
#          '애니메이션': 59,
#          '계열': 59,
#          '오스트레일리아': 59,
#          '연극': 59,
#          '기타리스트': 59,
#          '얘기': 58,
#          '노력': 58,
#          '입장': 58,
#          '게이': 58,
#          '제도': 58,
#          '어스': 58,
#          '링크': 58,
#          '작곡': 58,
#          '딜런': 57,
#          '보유': 57,
#          '거부': 57,
#          '한번': 57,
#          '인지도': 57,
#          '로부터': 57,
#          '스미스': 57,
#          '지정': 57,
#          '자랑': 57,
#          '대륙': 57,
#          '감소': 57,
#          '합법': 57,
#          '타이틀': 57,
#          '반대': 57,
#          '다운타운': 57,
#          '스티브': 57,
#          '상징': 56,
#          '주스': 56,
#          '부정': 56,
#          '끼리': 56,
#          '순위': 56,
#          '남자': 56,
#          '리스트': 56,
#          '롤링': 56,
#          '왕국': 56,
#          '가격': 56,
#          '화면': 56,
#          '파티': 56,
#          '절대': 55,
#          '기술': 55,
#          '재거': 55,
#          '출시': 55,
#          '올림픽': 55,
#          '변경': 55,
#          '대다수': 55,
#          '덕분': 55,
#          '적용': 55,
#          '유행': 55,
#          '당신': 55,
#          '프리미엄': 55,
#          '인생': 54,
#          '라디오': 54,
#          '중간': 54,
#          '본격': 54,
#          '충격': 54,
#          '특성': 54,
#          '아들': 54,
#          '또한': 54,
#          '크기': 54,
#          '혼혈': 54,
#          '사용자': 54,
#          '특정': 54,
#          '투표': 54,
#          '대회': 54,
#          '그래미상': 54,
#          '별로': 53,
#          '처럼': 53,
#          '몇몇': 53,
#          '요소': 53,
#          '키스': 53,
#          '한편': 53,
#          '소유': 53,
#          '차단': 53,
#          '주류': 53,
#          '규정': 53,
#          '음식': 53,
#          '형식': 53,
#          '촬영': 53,
#          '신고': 53,
#          '테일러': 53,
#          '동네': 52,
#          '그림': 52,
#          '스토리': 52,
#          '뮤직비디오': 52,
#          '관객': 52,
#          '국제': 52,
#          '이탈리아': 52,
#          '선거': 52,
#          '국민': 52,
#          '북부': 52,
#          '포드': 52,
#          '도중': 52,
#          '기억': 52,
#          '명칭': 52,
#          '리처드': 52,
#          '후반': 51,
#          '레이블': 51,
#          '버스': 51,
#          '위로': 51,
#          '미시간': 51,
#          '아트': 51,
#          '태평양': 51,
#          '언어': 51,
#          '요구': 51,
#          '역할': 51,
#          '보수': 51,
#          '실시': 51,
#          '의도': 51,
#          '한정': 50,
#          '비난': 50,
#          '달성': 50,
#          '특유': 50,
#          '하트': 50,
#          '미군': 50,
#          '가끔': 50,
#          '기후': 50,
#          '원인': 50,
#          '건설': 50,
#          '종종': 50,
#          '이동': 50,
#          '처리': 50,
#          '운영': 50,
#          '전반': 50,
#          '에미상': 50,
#          '작사': 49,
#          '화이트': 49,
#          '죽음': 49,
#          '의사': 49,
#          '공격': 49,
#          '싸움': 49,
#          '자료': 49,
#          '추천': 49,
#          '워싱턴': 49,
#          '독립': 49,
#          '승리': 49,
#          '대전': 49,
#          '별개': 49,
#          '호주': 49,
#          '어디': 49,
#          '전통': 49,
#          '대마초': 49,
#          '플레이어': 49,
#          '홀리': 49,
#          '콘서트': 48,
#          '큐브': 48,
#          '이주': 48,
#          '사운드트랙': 48,
#          '중반': 48,
#          '화제': 48,
#          '루이스': 48,
#          '지난': 48,
#          '등재': 48,
#          '여담': 48,
#          '형성': 48,
#          '마틴': 48,
#          '우승': 48,
#          '성우': 48,
#          '윌리엄스': 48,
#          '우린': 48,
#          '액자': 47,
#          '협업': 47,
#          '클럽': 47,
#          '헤일리': 47,
#          '정상': 47,
#          '은퇴': 47,
#          '검색': 47,
#          '커뮤니티': 47,
#          '추가': 47,
#          '남북': 47,
#          '작곡가': 47,
#          '통계': 47,
#          '도심': 47,
#          '도입': 47,
#          '예산': 47,
#          '장관': 47,
#          '종합': 47,
#          '도움': 46,
#          '비디오': 46,
#          '트럼프': 46,
#          '스스로': 46,
#          '존경': 46,
#          '수단': 46,
#          '진출': 46,
#          '브라질': 46,
#          '공유': 46,
#          '아래': 46,
#          '공화당': 46,
#          '형태': 46,
#          '대학교': 46,
#          '로빈슨': 46,
#          '출처': 46,
#          '임시': 46,
#          '로버트': 46,
#          '로우': 46,
#          '음악가': 45,
#          '제시': 45,
#          '폭력': 45,
#          '편견': 45,
#          '거물': 45,
#          '에디': 45,
#          '누가': 45,
#          '애초': 45,
#          '번역': 45,
#          '시행': 45,
#          '행사': 45,
#          '지구': 45,
#          '이민': 45,
#          '종교': 45,
#          '시설': 45,
#          '물건': 45,
#          '소울': 45,
#          '재즈': 45,
#          '기획': 45,
#          '타일러': 44,
#          '해체': 44,
#          '마일': 44,
#          '개봉': 44,
#          '이로': 44,
#          '회수': 44,
#          '슈퍼볼': 44,
#          '소식': 44,
#          '매체': 44,
#          '나머지': 44,
#          '시민': 44,
#          '무엇': 44,
#          '담당': 44,
#          '피해자': 44,
#          '외모': 44,
#          '오해': 44,
#          '타임': 44,
#          '코카소이드': 44,
#          '버니': 44,
#          '대해': 43,
#          '가정': 43,
#          '개월': 43,
#          '느낌': 43,
#          '반복': 43,
#          '프로듀싱': 43,
#          '대체': 43,
#          '주연': 43,
#          '부족': 43,
#          '적극': 43,
#          '활용': 43,
#          '아웃': 43,
#          '구입': 43,
#          '비만': 43,
#          '커버': 43,
#          '강제': 43,
#          '호평': 42,
#          '나중': 42,
#          '중단': 42,
#          '인지': 42,
#          '초반': 42,
#          '성과': 42,
#          '일종': 42,
#          '하자': 42,
#          '갈등': 42,
#          '테러': 42,
#          '항목': 42,
#          '샌프란시스코': 42,
#          '공장': 42,
#          '정의': 42,
#          '브랜드': 42,
#          '리틀': 42,
#          '보조': 42,
#          '제리': 42,
#          '브라이언': 42,
#          '금제': 42,
#          '플로우': 41,
#          '어워드': 41,
#          '잘못': 41,
#          '제일': 41,
#          '보호': 41,
#          '굳이': 41,
#          '바람': 41,
#          '워낙': 41,
#          '슬럼': 41,
#          '입지': 41,
#          '지속': 41,
#          '한계': 41,
#          '허용': 41,
#          '회담': 41,
#          '농구': 41,
#          '시즌': 41,
#          '동북아시아': 41,
#          '브루스': 40,
#          '올해': 40,
#          '추진': 40,
#          '최악': 40,
#          '비중': 40,
#          '일이': 40,
#          '소개': 40,
#          '스튜디오': 40,
#          '유엔': 40,
#          '지방': 40,
#          '추정': 40,
#          '자의': 40,
#          '구글': 40,
#          '정착': 40,
#          '장소': 40,
#          '버튼': 40,
#          '단속': 40,
#          '정식': 40,
#          '제조': 40,
#          '콘텐츠': 40,
#          '데이비스': 40,
#          '리볼버': 40,
#          '믹스': 40,
#          '앨범상': 40,
#          '왜냐면': 40,
#          '아레사': 39,
#          '요청': 39,
#          '의존': 39,
#          '동안': 39,
#          '루머': 39,
#          '다운로드': 39,
#          '장난': 39,
#          '간의': 39,
#          '체제': 39,
#          '지대': 39,
#          '일정': 39,
#          '대학': 39,
#          '휴대': 39,
#          '구매': 39,
#          '허가': 39,
#          '의료': 39,
#          '항의': 39,
#          '피트': 39,
#          '업무': 39,
#          '직업': 39,
#          '아랍인': 39,
#          '이드': 39,
#          '고대': 39,
#          '브라더스': 39,
#          '카트': 39,
#          '가입': 39,
#          '모바일': 39,
#          '이희호': 39,
#          '항상': 38,
#          '듯이': 38,
#          '직원': 38,
#          '인증': 38,
#          '신경': 38,
#          '마련': 38,
#          '리드': 38,
#          '리지': 38,
#          '기분': 38,
#          '영토': 38,
#          '베트남': 38,
#          '조건': 38,
#          '네덜란드': 38,
#          '한국어': 38,
#          '통합': 38,
#          '지지': 38,
#          '리그': 38,
#          '카운티': 38,
#          '기념': 38,
#          '트릭': 38,
#          '초창': 38,
#          '전파': 38,
#          '민자당': 38,
#          '징역': 38,
#          '담배': 37,
#          '전작': 37,
#          '섭취': 37,
#          '폭발': 37,
#          '진입': 37,
#          '알래스카': 37,
#          '무장': 37,
#          '개국': 37,
#          '타인': 37,
#          '조직': 37,
#          '시청': 37,
#          '철도': 37,
#          '통제': 37,
#          '협회': 37,
#          '예시': 37,
#          '유래': 37,
#          '방영': 37,
#          '작용': 37,
#          '다큐멘터리': 37,
#          '노출': 37,
#          '기원전': 37,
#          '해석': 37,
#          '권투': 37,
#          '삭제': 37,
#          '피아노': 37,
#          '사격': 37,
#          '플레이': 36,
#          '부터': 36,
#          '소위': 36,
#          '얼굴': 36,
#          '포기': 36,
#          '달라': 36,
#          '로스': 36,
#          '회복': 36,
#          '실시간': 36,
#          '살해': 36,
#          '개선': 36,
#          '드립': 36,
#          '질문': 36,
#          '코미디': 36,
#          '노선': 36,
#          '본토': 36,
#          '면적': 36,
#          '메인': 36,
#          '해결': 36,
#          '대가': 36,
#          '가량': 36,
#          '다그': 36,
#          '요인': 36,
#          '이남': 36,
#          '교외': 36,
#          '위키': 36,
#          '경험': 36,
#          '시스템': 36,
#          '근육': 36,
#          '표기': 36,
#          '패션': 36,
#          '갱스터': 36,
#          '린다': 36,
#          '별명': 36,
#          '시내': 36,
#          '요금': 36,
#          '가기': 36,
#          '연출': 36,
#          '사이먼': 36,
#          '라이': 36,
#          '토핀': 36,
#          '대응': 36,
#          ...})

# %%
la_word_result
# Out:
# Counter({'미국': 3213,
#          '지역': 1569,
#          '한국': 1427,
#          '영어': 1264,
#          '국가': 1132,
#          '일본': 1079,
#          '세계': 1069,
#          '경우': 984,
#          '사람': 981,
#          '영화': 965,
#          '스페인': 836,
#          '인구': 834,
#          '멕시코': 834,
#          '정도': 819,
#          '중국': 807,
#          '도시': 770,
#          '스페인어': 710,
#          '뉴욕': 707,
#          '원주민': 664,
#          '전쟁': 617,
#          '영국': 591,
#          '문제': 581,
#          '나라': 543,
#          '현재': 536,
#          '언어': 519,
#          '문화': 514,
#          '사용': 509,
#          '대부분': 489,
#          '캘리포니아': 488,
#          '정부': 487,
#          '독일': 469,
#          '시작': 466,
#          '디즈니': 457,
#          '이민': 451,
#          '세기': 442,
#          '기후': 430,
#          '때문': 422,
#          '보잉': 418,
#          '대학': 414,
#          '편이': 411,
#          '경제': 406,
#          '할리우드': 403,
#          '사회': 400,
#          '대학교': 398,
#          '존재': 382,
#          '수준': 382,
#          '위치': 376,
#          '유럽': 373,
#          '프랑스': 370,
#          '제국': 369,
#          '대표': 366,
#          '하나': 363,
#          '학교': 363,
#          '발음': 362,
#          '공화국': 362,
#          '출신': 360,
#          '이름': 356,
#          '아메리카': 353,
#          '대한민국': 347,
#          '관련': 345,
#          '사막': 343,
#          '정치': 340,
#          '일부': 337,
#          '영향': 337,
#          '캐나다': 329,
#          '백인': 324,
#          '로스앤젤레스': 320,
#          '히스패닉': 317,
#          '남부': 314,
#          '자체': 313,
#          '가지': 312,
#          '주의': 310,
#          '관계': 307,
#          '감독': 303,
#          '역사': 301,
#          '이유': 298,
#          '포함': 293,
#          '소련': 289,
#          '참고': 288,
#          '러시아': 285,
#          '미국인': 285,
#          '시리즈': 284,
#          '지금': 282,
#          '상황': 277,
#          '이후': 276,
#          '샌프란시스코': 275,
#          '생각': 275,
#          '단어': 275,
#          '수도': 273,
#          '아시아': 272,
#          '워싱턴': 268,
#          '개발': 267,
#          '전반': 266,
#          '전체': 263,
#          '거주': 262,
#          '교육': 261,
#          '독립': 258,
#          '기도': 256,
#          '서부': 255,
#          '대전': 254,
#          '사실': 253,
#          '제외': 251,
#          '규모': 247,
#          '여러': 247,
#          '아르메니아': 246,
#          '민족': 245,
#          '기준': 244,
#          '흑인': 243,
#          '부족': 243,
#          '카운티': 239,
#          '학생': 239,
#          '민주당': 239,
#          '의미': 234,
#          '이탈리아': 234,
#          '사건': 231,
#          '영토': 230,
#          '왕국': 230,
#          '중심': 229,
#          '한국인': 229,
#          '한국어': 228,
#          '달리': 227,
#          '시기': 227,
#          '에티오피아': 226,
#          '배경': 223,
#          '천사': 219,
#          '평균': 218,
#          '여기': 217,
#          '시장': 217,
#          '연방': 217,
#          '기술': 217,
#          '지방': 217,
#          '제작': 214,
#          '부분': 213,
#          '작품': 213,
#          '이상': 212,
#          '생산': 209,
#          '본토': 208,
#          '회사': 208,
#          '표현': 208,
#          '산업': 207,
#          '크게': 206,
#          '차이': 206,
#          '대통령': 206,
#          '프랑스어': 205,
#          '북부': 203,
#          '이기': 203,
#          '사이': 203,
#          '발생': 202,
#          '치안': 200,
#          '제도': 200,
#          '표기': 199,
#          '과거': 199,
#          '등장': 198,
#          '대륙': 198,
#          '스튜디오': 197,
#          '식민지': 194,
#          '정책': 194,
#          '거리': 193,
#          '주민': 191,
#          '최고': 190,
#          '지진': 189,
#          '자주': 188,
#          '게임': 187,
#          '용어': 186,
#          '이민자': 185,
#          '국제': 185,
#          '아예': 183,
#          '인도': 182,
#          '호주': 180,
#          '홍콩': 178,
#          '면적': 177,
#          '원래': 177,
#          '마찬가지': 177,
#          '시절': 176,
#          '거나': 176,
#          '주요': 174,
#          '피해': 174,
#          '차지': 173,
#          '유지': 172,
#          '과정': 167,
#          '최초': 166,
#          '태국': 166,
#          '사례': 165,
#          '달러': 165,
#          '비롯': 164,
#          '시대': 164,
#          '대도시': 162,
#          '냉전': 161,
#          '기업': 161,
#          '최근': 160,
#          '분야': 160,
#          '맨해튼': 159,
#          '동부': 156,
#          '기록': 156,
#          '행정구역': 156,
#          '이전': 156,
#          '북한': 156,
#          '외교': 156,
#          '일반': 154,
#          '아프리카': 154,
#          '싱가포르': 154,
#          '흥행': 154,
#          '실제': 153,
#          '사업': 153,
#          '속령': 153,
#          '상태': 152,
#          '처음': 152,
#          '브라질': 152,
#          '어휘': 152,
#          '경찰': 151,
#          '행정구': 151,
#          '인종': 150,
#          '여름': 150,
#          '쿠바': 150,
#          '비교': 149,
#          '중남미': 149,
#          '아르헨티나': 149,
#          '관사': 148,
#          '최대': 148,
#          '구분': 148,
#          '자신': 148,
#          '해당': 147,
#          '시티': 147,
#          '해도': 147,
#          '반면': 147,
#          '화교': 147,
#          '현대': 146,
#          '차이나타운': 146,
#          '영향력': 146,
#          '지원': 146,
#          '시스템': 146,
#          '한인': 144,
#          '진행': 144,
#          '애니메이션': 144,
#          '항공': 144,
#          '이자': 143,
#          '시간': 143,
#          '주장': 143,
#          '상대': 143,
#          '필리핀': 143,
#          '현상': 142,
#          '투자': 141,
#          '대신': 141,
#          '문명': 140,
#          '자유': 139,
#          '태평양': 138,
#          '평가': 138,
#          '리그': 138,
#          '외국인': 138,
#          '비율': 138,
#          '정보': 138,
#          '직접': 137,
#          '공화당': 137,
#          '건물': 136,
#          '폭스': 136,
#          '변화': 136,
#          '포르투갈': 136,
#          '사항': 135,
#          '지정': 134,
#          '공식': 134,
#          '자리': 133,
#          '인기': 133,
#          '나치': 133,
#          '칠레': 133,
#          '발전': 132,
#          '모습': 132,
#          '아일랜드': 132,
#          '형태': 132,
#          '지리': 131,
#          '세대': 131,
#          '계속': 130,
#          '라틴아메리카': 130,
#          '국민': 129,
#          '이야기': 128,
#          '주변': 127,
#          '인식': 127,
#          '여성': 127,
#          '서울': 126,
#          '역할': 126,
#          '요리': 126,
#          '그대로': 126,
#          '촬영': 126,
#          '합의': 126,
#          '언급': 125,
#          '기온': 124,
#          '결과': 123,
#          '가톨릭': 123,
#          '해외': 123,
#          '성향': 123,
#          '코리아타운': 122,
#          '동네': 122,
#          '이용': 122,
#          '인정': 122,
#          '고등학교': 122,
#          '특성': 121,
#          '항공기': 121,
#          '기존': 120,
#          '텍사스': 120,
#          '배우': 120,
#          '운동': 120,
#          '종교': 120,
#          '로서': 119,
#          '명사': 119,
#          '상징': 119,
#          '칼텍': 119,
#          '마틴': 117,
#          '관광': 117,
#          '수가': 117,
#          '출산율': 117,
#          '방식': 116,
#          '네덜란드': 116,
#          '동사': 116,
#          '보통': 115,
#          '명칭': 115,
#          '방언': 115,
#          '증가': 114,
#          '국경': 114,
#          '해군': 114,
#          '장비': 114,
#          '북미': 113,
#          '당시': 113,
#          '사고': 113,
#          '지대': 112,
#          '지배': 112,
#          '대만': 112,
#          '토론': 112,
#          '취업': 111,
#          '전통': 110,
#          '생활': 110,
#          '튀르키예': 110,
#          '집중': 109,
#          '록히드': 109,
#          '보유': 109,
#          '일본인': 109,
#          '활동': 109,
#          '묘사': 108,
#          '중앙': 108,
#          '남성': 107,
#          '주인공': 107,
#          '영주권': 107,
#          '문서': 106,
#          '세력': 106,
#          '국토': 106,
#          '연합국': 105,
#          '선진국': 105,
#          '요소': 105,
#          '분류': 105,
#          '뉴욕시': 104,
#          '다음': 104,
#          '구역': 104,
#          '기본': 104,
#          '언론': 104,
#          '왕조': 104,
#          '적용': 103,
#          '교통': 103,
#          '라면': 103,
#          '참조': 103,
#          '분위기': 102,
#          '겨울': 102,
#          '일대': 102,
#          '경쟁': 102,
#          '미군': 102,
#          '더욱': 102,
#          '뉴질랜드': 102,
#          '아제르바이잔': 102,
#          '예술': 101,
#          '요구': 101,
#          '폴란드': 101,
#          '현지': 100,
#          '전투': 100,
#          '한편': 100,
#          '코로나': 100,
#          '아주': 99,
#          '사진': 99,
#          '방송': 99,
#          '중이': 99,
#          '제대로': 99,
#          '연구': 99,
#          '정권': 99,
#          '발견': 98,
#          '서로': 98,
#          '선수': 98,
#          '파크': 98,
#          '비판': 98,
#          '환경': 97,
#          '스포츠': 97,
#          '논란': 97,
#          '스타': 96,
#          '강수량': 95,
#          '경향': 95,
#          '외국어': 95,
#          '계획': 95,
#          '개척': 94,
#          '국적': 94,
#          '가뭄': 94,
#          '소속': 94,
#          '운영': 94,
#          '선거': 94,
#          '우리': 94,
#          '입장': 94,
#          '기반': 93,
#          '근처': 93,
#          '진출': 93,
#          '대다수': 93,
#          '인간': 93,
#          '그것': 93,
#          '중국어': 92,
#          '그룹': 92,
#          '덕분': 92,
#          '인근': 92,
#          '소득': 92,
#          '중국인': 92,
#          '축구': 92,
#          '점령': 92,
#          '정착': 91,
#          '도쿄': 91,
#          '가능성': 91,
#          '범죄': 91,
#          '베이': 91,
#          '체제': 91,
#          '혈통': 91,
#          '센터': 90,
#          '워낙': 90,
#          '발달': 90,
#          '계열': 90,
#          '개봉': 90,
#          '알래스카': 90,
#          '그리스': 90,
#          '전세계': 90,
#          '자국': 90,
#          '개념': 90,
#          '비자': 90,
#          '제작사': 90,
#          '초기': 89,
#          '도로': 89,
#          '통계': 89,
#          '인수': 89,
#          '집단': 89,
#          '오늘날': 89,
#          '유학': 89,
#          '학살': 89,
#          '브루클린': 88,
#          '지구': 88,
#          '인물': 88,
#          '현실': 88,
#          '이주': 88,
#          '캐릭터': 88,
#          '페루': 88,
#          '광역권': 87,
#          '부촌': 87,
#          '캠퍼스': 87,
#          '오브': 87,
#          '취급': 87,
#          '조약': 87,
#          '법칙': 87,
#          '전혀': 86,
#          '정작': 86,
#          '보이': 86,
#          '구성': 86,
#          '총기': 86,
#          '교회': 85,
#          '형성': 85,
#          '특징': 85,
#          '결정': 85,
#          '정말': 85,
#          '방법': 85,
#          '전국': 85,
#          '교수': 85,
#          '포르투갈어': 85,
#          '지중해': 84,
#          '가면': 84,
#          '사태': 84,
#          '보기': 84,
#          '군사': 84,
#          '로부터': 84,
#          '침공': 84,
#          '마블': 84,
#          '프로듀서': 84,
#          '건설': 83,
#          '음식': 83,
#          '영상': 83,
#          '별로': 83,
#          '이미지': 83,
#          '필요': 83,
#          '독일어': 83,
#          '참여': 83,
#          '이해': 83,
#          '자연': 82,
#          '압도': 82,
#          '시설': 82,
#          '우승': 82,
#          '가족': 82,
#          '대상': 82,
#          '멕시코인': 82,
#          '비중': 81,
#          '무려': 81,
#          '플로리다': 81,
#          '예외': 81,
#          '대형': 81,
#          '노래': 80,
#          '디자인': 80,
#          '발표': 80,
#          '의회': 80,
#          '유대인': 80,
#          '시험': 80,
#          '관리': 79,
#          '몇몇': 79,
#          '애초': 79,
#          '조선': 79,
#          '부모': 79,
#          '표준': 79,
#          '라틴어': 79,
#          '고대': 79,
#          '라틴': 78,
#          '월트': 78,
#          '먼저': 78,
#          '지지': 78,
#          '단위': 77,
#          '수도권': 77,
#          '기간': 77,
#          '노력': 77,
#          '연합': 77,
#          '더글라스': 77,
#          '정교회': 77,
#          '전기': 77,
#          '조사': 76,
#          '분리': 76,
#          '순위': 76,
#          '북아메리카': 76,
#          '자치': 76,
#          '부산': 76,
#          '문자': 76,
#          '문법': 76,
#          '남쪽': 75,
#          '고도': 75,
#          '제임스': 75,
#          '상업': 75,
#          '도입': 75,
#          '인디언': 75,
#          '유래': 74,
#          '또한': 74,
#          '명의': 74,
#          '버스': 74,
#          '국내': 74,
#          '감소': 74,
#          '컬럼비아': 74,
#          '설명': 74,
#          '대학원': 73,
#          '자동차': 73,
#          '후반': 73,
#          '거기': 73,
#          '위기': 73,
#          '베네수엘라': 73,
#          '영어권': 73,
#          '공동체': 72,
#          '대비': 72,
#          '보고': 72,
#          '의견': 72,
#          '그래프': 72,
#          '전차': 72,
#          '문장': 71,
#          '소재': 71,
#          '타고': 71,
#          '적도': 71,
#          '조직': 71,
#          '본인': 71,
#          '바람': 71,
#          '하나로': 71,
#          '아이': 71,
#          '선택': 71,
#          '내전': 71,
#          '건국': 71,
#          '졸업': 71,
#          '콜롬비아': 71,
#          '픽처스': 71,
#          '자음': 70,
#          '중반': 70,
#          '공항': 70,
#          '행정': 70,
#          '사망': 70,
#          '특정': 70,
#          '한반도': 70,
#          '아래': 70,
#          '초반': 70,
#          '가격': 70,
#          '적극': 70,
#          '유입': 70,
#          '폐지': 70,
#          '윌리엄': 70,
#          '추축국': 70,
#          '푸에르토리코': 70,
#          '소수': 70,
#          '관광객': 70,
#          '갈등': 69,
#          '방문': 69,
#          '기관': 69,
#          '엔터테인먼트': 69,
#          '단체': 69,
#          '중부': 69,
#          '월드': 69,
#          '아버지': 69,
#          '잉글랜드': 69,
#          '맥도넬': 69,
#          '상당수': 68,
#          '전투기': 68,
#          '자랑': 68,
#          '정체': 68,
#          '장면': 68,
#          '성적': 68,
#          '로마': 68,
#          '중간': 67,
#          '공장': 67,
#          '지도': 67,
#          '조지': 67,
#          '진학': 67,
#          '일본어': 67,
#          '취득': 67,
#          '참전': 67,
#          '보호': 67,
#          '자원': 67,
#          '능력': 67,
#          '비용': 67,
#          '스스로': 67,
#          '공군': 67,
#          '다저스': 66,
#          '수업': 66,
#          '소리': 66,
#          '업체': 66,
#          '산맥': 66,
#          '이탈리아어': 66,
#          '남아메리카': 66,
#          '공부': 66,
#          '총리': 66,
#          '국가대표팀': 66,
#          '규슈': 66,
#          '하와이': 65,
#          '다수': 65,
#          '우루과이': 65,
#          '신청': 65,
#          '한자': 64,
#          '가습기': 64,
#          '동쪽': 64,
#          '이외': 64,
#          '커피': 64,
#          '철도': 64,
#          '분쟁': 64,
#          '기능': 64,
#          '우크라이나': 64,
#          '개인': 64,
#          '작전': 64,
#          '의식': 64,
#          '카를로스': 64,
#          '아즈텍': 64,
#          '북쪽': 63,
#          '대규모': 63,
#          '극장': 63,
#          '유명': 63,
#          '본격': 63,
#          '본사': 63,
#          '굳이': 63,
#          '여객기': 63,
#          '만화': 63,
#          '보장': 63,
#          '식민': 63,
#          '조건': 63,
#          '수입': 63,
#          '기사': 63,
#          '반발': 63,
#          '헌법': 63,
#          '이란': 63,
#          '마카오': 63,
#          '차량': 63,
#          '영화사': 63,
#          '제일': 62,
#          '주도': 62,
#          '개선': 62,
#          '경계': 62,
#          '내용': 62,
#          '시도': 62,
#          '동아시아': 62,
#          '베트남': 62,
#          '공격': 62,
#          '밀도': 62,
#          '혼혈': 62,
#          '부정': 62,
#          '조지아': 62,
#          '국방': 62,
#          '비만': 62,
#          '모로코': 62,
#          '종종': 61,
#          '공립': 61,
#          '사립': 61,
#          '행사': 61,
#          '승리': 61,
#          '구조': 61,
#          '농업': 61,
#          '가운데': 61,
#          '헝가리': 61,
#          '마지막': 61,
#          '강조': 61,
#          '노스롭': 60,
#          '해양': 60,
#          '서쪽': 60,
#          '음악': 60,
#          '학부': 60,
#          '위협': 60,
#          '목적': 60,
#          '설정': 60,
#          '위주': 60,
#          '가정': 60,
#          '보수': 60,
#          '교류': 60,
#          '시리아': 60,
#          '남미': 60,
#          '통합': 60,
#          '중심지': 59,
#          '특유': 59,
#          '외국': 59,
#          '타운': 59,
#          '필수': 59,
#          '시카고': 59,
#          '경기': 59,
#          '무대': 59,
#          '숫자': 59,
#          '어디': 59,
#          '반도': 59,
#          '반영': 59,
#          '서유럽': 59,
#          '관심': 59,
#          '동물': 59,
#          '학기': 59,
#          '지명': 58,
#          '역대': 58,
#          '날씨': 58,
#          '해안': 58,
#          '전문': 58,
#          '올림픽': 58,
#          '시민': 58,
#          '이제': 58,
#          '크기': 58,
#          '국제공항': 58,
#          '매체': 58,
#          '규제': 58,
#          '금지': 58,
#          '시민권': 58,
#          '해결': 58,
#          '주류': 58,
#          '이스라엘': 58,
#          '식당': 58,
#          '종류': 58,
#          '정복': 58,
#          '홋카이도': 58,
#          '복수': 57,
#          '시내': 57,
#          '시모노세키': 57,
#          '드라마': 57,
#          '절대': 57,
#          '아메리칸': 57,
#          '반대': 57,
#          '성인': 57,
#          '오스트리아': 57,
#          '대해': 57,
#          '인터넷': 57,
#          '여권': 57,
#          '위성도시': 56,
#          '하위': 56,
#          '제한': 56,
#          '기초': 56,
#          '구사': 56,
#          '설립': 56,
#          '연안': 56,
#          '바다': 56,
#          '동유럽': 56,
#          '선언': 56,
#          '중화민국': 56,
#          '점점': 56,
#          '대체로': 56,
#          '마을': 55,
#          '성공': 55,
#          '추세': 55,
#          '예산': 55,
#          '매년': 55,
#          '프로': 55,
#          '마약': 55,
#          '사랑': 55,
#          '항상': 55,
#          '비난': 55,
#          '트럼프': 55,
#          '효과': 55,
#          '혁명': 55,
#          '사법': 55,
#          '불가리아': 55,
#          '건조': 55,
#          '메이저': 55,
#          '육군': 55,
#          '활용': 55,
#          '수상자': 55,
#          '협력': 55,
#          '군대': 54,
#          '본래': 54,
#          '스페인인': 54,
#          '진보': 54,
#          '분포': 54,
#          '널리': 54,
#          '여자': 54,
#          '이동': 54,
#          '애리조나': 54,
#          '지위': 54,
#          '붕괴': 54,
#          '노동': 54,
#          '학과': 54,
#          '지속': 54,
#          '규정': 54,
#          '항목': 54,
#          '스페인령': 54,
#          '노르웨이': 54,
#          '사과': 54,
#          '번역': 54,
#          '배급': 54,
#          '자격': 54,
#          '로스': 53,
#          '박물관': 53,
#          '장소': 53,
#          '추진': 53,
#          '멤버': 53,
#          '시즌': 53,
#          '지사': 53,
#          '인천': 53,
#          '합병': 53,
#          '장점': 53,
#          '원인': 53,
#          '머리': 53,
#          '국기': 53,
#          '제품': 53,
#          '수단': 53,
#          '벨기에': 53,
#          '집권': 53,
#          '스타워즈': 53,
#          '남자': 53,
#          '남아프리카': 53,
#          '항공사': 53,
#          '중세': 53,
#          '항구': 52,
#          '한정': 52,
#          '런던': 52,
#          '지하철': 52,
#          '후보': 52,
#          '확장': 52,
#          '야구': 52,
#          '위원회': 52,
#          '내부': 52,
#          '도미니카': 52,
#          '파키스탄': 52,
#          '덴마크': 52,
#          '스위스': 52,
#          '군용기': 52,
#          '볼리비아': 52,
#          '갱스터': 51,
#          '대로': 51,
#          '의료': 51,
#          '탄생': 51,
#          '상위': 51,
#          '개신교': 51,
#          '프로그램': 51,
#          '대선': 51,
#          '연결': 51,
#          '뉴스': 51,
#          '선호': 51,
#          '유럽인': 51,
#          '강제': 51,
#          '인력': 51,
#          '미합중국': 51,
#          '무엇': 51,
#          '절반': 51,
#          '병원': 51,
#          '히틀러': 51,
#          '에콰도르': 51,
#          '수행': 51,
#          '운용': 51,
#          '노동자': 50,
#          '도시권': 50,
#          '이웃': 50,
#          '영역': 50,
#          '시애틀': 50,
#          '예정': 50,
#          '가끔': 50,
#          '위로': 50,
#          '투표': 50,
#          '판매': 50,
#          '속도': 50,
#          '전역': 50,
#          '파나마': 50,
#          '부동산': 50,
#          '우려': 50,
#          '예시': 50,
#          '인지': 50,
#          '유엔': 50,
#          '이라크': 50,
#          '자녀': 50,
#          '인도네시아': 50,
#          '과학': 50,
#          '클럽': 50,
#          '외래어': 50,
#          '계약': 50,
#          '이베리아': 50,
#          '나성': 49,
#          '적지': 49,
#          '대개': 49,
#          '간의': 49,
#          '대가': 49,
#          '가량': 49,
#          '아르': 49,
#          '무시': 49,
#          '성격': 49,
#          '노선': 49,
#          '직원': 49,
#          '파괴': 49,
#          '세금': 49,
#          '통과': 49,
#          '차별': 49,
#          '확보': 49,
#          '준비': 49,
#          '루이지애나': 49,
#          '민주': 49,
#          '불교': 49,
#          '자료': 49,
#          '전설': 49,
#          '시행': 49,
#          '과테말라': 49,
#          '베이징': 49,
#          '신문': 49,
#          '모음': 49,
#          '위상': 48,
#          '거문도': 48,
#          '체계': 48,
#          '도심': 48,
#          '앞서': 48,
#          '구장': 48,
#          '다가': 48,
#          '곳도': 48,
#          '빌딩': 48,
#          '포기': 48,
#          '모티브': 48,
#          '접근': 48,
#          '확인': 48,
#          '보도': 48,
#          '대지진': 48,
#          '센트럴': 48,
#          '주가': 48,
#          '등지': 48,
#          '대거': 48,
#          '국장': 48,
#          '인민': 48,
#          '저출산': 48,
#          '모국어': 48,
#          '소총': 48,
#          '우주': 48,
#          '합류': 48,
#          '하느님': 48,
#          '그루': 48,
#          '남아': 47,
#          '계기': 47,
#          '미디어': 47,
#          '나머지': 47,
#          '무역': 47,
#          '명문': 47,
#          '간판': 47,
#          '추가': 47,
#          '사상': 47,
#          '실질': 47,
#          '자금': 47,
#          '이로': 47,
#          '대체': 47,
#          '일상': 47,
#          '루마니아': 47,
#          '수치': 47,
#          '아랍어': 47,
#          '점수': 47,
#          '필름': 47,
#          '보병': 47,
#          '편입': 46,
#          '과목': 46,
#          '지형': 46,
#          '남한': 46,
#          '부왕': 46,
#          '부담': 46,
#          '고려': 46,
#          '테러': 46,
#          '어머니': 46,
#          '진짜': 46,
#          '창작': 46,
#          '공산주의': 46,
#          '스페인어권': 45,
#          '아파트': 45,
#          '시위': 45,
#          '라이벌': 45,
#          '뉴저지': 45,
#          '대응': 45,
#          '패러디': 45,
#          '블랙': 45,
#          ...})

# %% [markdown]
# ```
#
# for paragraph in paragraphs:
#     if not paragraph.find("a", class_="wiki-link-external"):
#         filtered_paragraphs.append(paragraph)
# ```
# 이 코드 블럭은 추가했었지만 없앴다.
#
# 에미넴 문서의 관련 문서인 닥터드레 문서는 코드 블럭이 없으면
#
# [ 펼치기 · 접기 ]이희호이희호 문서의 r779 판, 번 문단 (이전 역사)명예훼손죄명예훼손죄 문서의 r75 판, 번 문단 (이전 역사) 문서의 r 판, 번 문단 (이전 역사) 문서의 r 판, 번 문단 (이전 역사) 문서의 r 판, 번 문단 (이전 역사) 문서의 r 판, 번 문단 (이전 역사) 문서의 r 판, 번 문단 (이전 역사) 문서의 r 판, 번 문단 (이전 역사) 문서의 r 판, 번 문단 (이전 역사) 문서의 r 판, 번 문단 (이전 역사) 문서의 r 판, 번 문단 (이전 역사) 문서의 r 판, 번 문단 (이전 역사) 문서의 r 판, 번 문단 (이전 역사) 문서의 r 판, 번 문단 (이전 역사) 문서의 r 판, 번 문단 (이전 역사) 문서의 r 판, 번 문단 (이전 역사) 문서의 r 판, 번 문단 (이전 역사) 문서의 r 판, 번 문단 (이전 역사) 문서의 r 판, 번 문단 (이전 역사) 문서의 r 판, 번 문단 (이전 역사) 문서의 r 판, 번 문단 (이전 역사) 문서의 r 판, 번 문단 (이전 역사) 문서의 r 판, 번 문단 (이전 역사) 문서의 r 판, 번 문단 (이전 역사) 문서의 r 판, 번 문단 (이전 역사) 문서의 r 판, 번 문단 (이전 역사) 문서의 r 판, 번 문단 (이전 역사) 문서의 r 판, 번 문단 (이전 역사) 문서의 r 판, 번 문단 (이전 역사) 문서의 r 판, 번 문단 (이전 역사) 문서의 r 판, 번 문단 (이전 역사) 문서의 r 판, 번 문단 (이전 역사) 문서의 r 판, 번 문단 (이전 역사) 문서의 r 판, 번 문단 (이전 역사) 문서의 r 판, 번 문단 (이전 역사) 문서의 r 판, 번 문단 (이전 역사) 문서의 r 판, 번 문단 (이전 역사) 문서의 r 판, 번 문단 (이전 역사) 문서의 r 판, 번 문단 (이전 역사) 문서의 r 판, 번 문단 (이전 역사) 문서의 r 판, 번 문단 (이전 역사) 문서의 r 판, 번 문단 (이전 역사) 문서의 r 판, 번 문단 (이전 역사) 문서의 r 판, 번 문단 (이전 역사) 문서의 r 판, 번 문단 (이전 역사) 문서의 r 판, 번 문단 (이전 역사) 문서의 r 판, 번 문단 (이전 역사) 문서의 r 판, 번 문단 (이전 역사) 문서의 r 판, 번 문단 (이전 역사) 문서의 r 판, 번 문단 (이전 역사)'
# 처럼 반복된다.
#
# 반면 또다른 관련 문서인
# G-funk 문서는위의 코드드 블럭이있없으면 내용이 없어진다.
# 따라서 코드 블럭은 제거하고 stopword에 추가한다.
# 또한 글자 길이가 1인 글자는 제거하도록 했다.)

# %% [markdown]
# https://namu.wiki/w/%EC%8A%A4%ED%83%80%EC%9D%BC%EB%A6%AC%EC%8B%9C
